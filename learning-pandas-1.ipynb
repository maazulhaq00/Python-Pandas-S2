# %%
# !pip install pandas
# Out:
# ...
#    ---------------------------------------- 0.0/11.1 MB ? eta -:--:--
#    ---------------------------------------- 0.0/11.1 MB ? eta -:--:--
#    - -------------------------------------- 0.5/11.1 MB 2.5 MB/s eta 0:00:05
#    ------ --------------------------------- 1.8/11.1 MB 5.4 MB/s eta 0:00:02
#    ---------- ----------------------------- 2.9/11.1 MB 5.0 MB/s eta 0:00:02
#    ----------------- ---------------------- 5.0/11.1 MB 6.2 MB/s eta 0:00:01
#    ------------------------ --------------- 6.8/11.1 MB 6.7 MB/s eta 0:00:01
#    --------------------------------- ------ 9.4/11.1 MB 7.8 MB/s eta 0:00:01
#    ---------------------------------------  11.0/11.1 MB 8.1 MB/s eta 0:00:01
#    ---------------------------------------- 11.1/11.1 MB 7.6 MB/s  0:00:01
# ...
#
#    ---------------------------------------- 0/2 [pytz]
#    ---------------------------------------- 0/2 [pytz]
#    ---------------------------------------- 0/2 [pytz]
# ...

# %%
import pandas as pd

# %%
#series
s1 = pd.Series([10, 20, 30, 40])
print(s1)
print(s1[3])
# Out:
# 0    10
# 1    20
# 2    30
# 3    40
# dtype: int64
# 40

# %%
marks_series = pd.Series([23, 44, 21, 32, 22], index=['Anas', 'Zaeema', 'Hamza', 'Razan', 'Usman'])

print(marks_series)
print(marks_series['Hamza'])
# Out:
# Anas      23
# Zaeema    44
# Hamza     21
# Razan     32
# Usman     22
# dtype: int64
# 21

# %%
students_data = {
    "Name" : ["Muheet" ,"Anas", "Saad", "Razan", "Zaeema", "Hamza", "Tabish", "Usman"],
    "Age": [14, 17, 18, 19, 15, 21, 19,18],
    "Score" : [99, 88, 77, 98, 87,87, 98, 87] 
}

print(students_data)

students_df = pd.DataFrame(students_data)

print(students_df)
# Out:
# {'Name': ['Muheet', 'Anas', 'Saad', 'Razan', 'Zaeema', 'Hamza', 'Tabish', 'Usman'], 'Age': [14, 17, 18, 19, 15, 21, 19, 18], 'Score': [99, 88, 77, 98, 87, 87, 98, 87]}
#      Name  Age  Score
# 0  Muheet   14     99
# 1    Anas   17     88
# 2    Saad   18     77
# 3   Razan   19     98
# 4  Zaeema   15     87
# 5   Hamza   21     87
# 6  Tabish   19     98
# 7   Usman   18     87

# %%
students_df
# Out:
#      Name  Age  Score
# 0  Muheet   14     99
# 1    Anas   17     88
# 2    Saad   18     77
# 3   Razan   19     98
# 4  Zaeema   15     87
# 5   Hamza   21     87
# 6  Tabish   19     98
# 7   Usman   18     87

# %%
students_df['Name']
# Out:
# 0    Muheet
# 1      Anas
# 2      Saad
# 3     Razan
# 4    Zaeema
# 5     Hamza
# 6    Tabish
# 7     Usman
# Name: Name, dtype: object

# %%
students_df['Age']
# Out:
# 0    14
# 1    17
# 2    18
# 3    19
# 4    15
# 5    21
# 6    19
# 7    18
# Name: Age, dtype: int64

# %%
students_df.loc[2]
# Out:
# Name     Saad
# Age        18
# Score      77
# Name: 2, dtype: object

# %%
students_df.loc[0]
# Out:
# Name     Muheet
# Age          14
# Score        99
# Name: 0, dtype: object

# %%
students_df[['Name', 'Score']]
# Out:
#      Name  Score
# 0  Muheet     99
# 1    Anas     88
# 2    Saad     77
# 3   Razan     98
# 4  Zaeema     87
# 5   Hamza     87
# 6  Tabish     98
# 7   Usman     87
